# %%
import numpy as np
import pandas as pd
import optuna
from xgboost import XGBClassifier
from sklearn.model_selection import StratifiedKFold
from optuna.samplers import TPESampler
from optuna.pruners import SuccessiveHalvingPruner

# %%
df_data = pd.read_csv('data/iris.csv', sep=',')
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
from sklearn.preprocessing import LabelEncoder

items=['Setosa', 'Versicolor', 'Virginica']
encoder = LabelEncoder()
encoder.fit(items)
df_data['variety'] = encoder.transform(df_data['variety'])
df_data.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width  variety
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df_data, test_size=0.2)

# %%
df_train.head()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety
# 76            6.8          2.8           4.8          1.4        1
# 85            6.0          3.4           4.5          1.6        1
# 137           6.4          3.1           5.5          1.8        2
# 8             4.4          2.9           1.4          0.2        0
# 127           6.1          3.0           4.9          1.8        2

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120 entries, 76 to 130
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  120 non-null    float64
#  1   sepal.width   120 non-null    float64
#  2   petal.length  120 non-null    float64
#  3   petal.width   120 non-null    float64
#  4   variety       120 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.2 KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 82 to 120
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  30 non-null     float64
#  1   sepal.width   30 non-null     float64
#  2   petal.length  30 non-null     float64
#  3   petal.width   30 non-null     float64
#  4   variety       30 non-null     int32
# dtypes: float64(4), int32(1)
# memory usage: 1.3 KB

# %%
features = ['sepal.length', 'sepal.width', 'petal.length', 'petal.width']
target = 'variety'

# %%
df_train.reset_index()
# Out:
#      index  sepal.length  sepal.width  petal.length  petal.width  variety
# 0       76           6.8          2.8           4.8          1.4        1
# 1       85           6.0          3.4           4.5          1.6        1
# 2      137           6.4          3.1           5.5          1.8        2
# 3        8           4.4          2.9           1.4          0.2        0
# 4      127           6.1          3.0           4.9          1.8        2
# ..     ...           ...          ...           ...          ...      ...
# 115    108           6.7          2.5           5.8          1.8        2
# 116     35           5.0          3.2           1.2          0.2        0
# 117     29           4.7          3.2           1.6          0.2        0
# 118     26           5.0          3.4           1.6          0.4        0
# 119    130           7.4          2.8           6.1          1.9        2
#
# [120 rows x 6 columns]

# %%
df_trains = []
df_valids = []
skf = StratifiedKFold(n_splits=5, random_state=0, shuffle=True)
for train_index, valid_index in skf.split(df_train[features], df_train[target]):
    train = df_train.iloc[train_index]
    valid = df_train.iloc[valid_index]
    df_trains.append(train)
    df_valids.append(valid)

# %%
import optuna
def accuracy(true, pred):
    return np.mean(true==pred)

def objective(trial):
    # params = {
    #     'num_leaves': trial.suggest_int('num_leaves', 2, 1024, step=1, log=True), 
    #     'max_depth': trial.suggest_int('max_depth', 1, 10, step=1, log=False), 
    #     'learning_rate': trial.suggest_float('learning_rate', 0.0001, 0.1, log=True), 
    #     'n_estimators': trial.suggest_int('n_estimators', 8, 1024, step=1, log=True), 
    #     'objective': 'multiclass', 
    #     'class_weight': trial.suggest_categorical('class_weight', ['balanced', None]),
    #     'min_child_samples': trial.suggest_int('min_child_samples', 10, 50, step=1, log=False), 
    #     'subsample': trial.suggest_uniform('subsample', 0.7, 1.0), 
    #     'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
    #     'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
    #     'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
    #     'random_state': 0
    # }
    params = {
        "verbosity": 0,
        "objective": "binary:logistic",
        # use exact for small dataset.
        "tree_method": "exact",
        # defines booster, gblinear for linear functions.
        "booster": trial.suggest_categorical("booster", ["gbtree", "gblinear", "dart"]),
        # L2 regularization weight.
        "lambda": trial.suggest_float("lambda", 1e-8, 1.0, log=True),
        # L1 regularization weight.
        "alpha": trial.suggest_float("alpha", 1e-8, 1.0, log=True),
        # sampling ratio for training data.
        "subsample": trial.suggest_float("subsample", 0.2, 1.0),
        # sampling according to each tree.
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.2, 1.0),
    }

    if params["booster"] in ["gbtree", "dart"]:
        # maximum depth of the tree, signifies complexity of the tree.
        params["max_depth"] = trial.suggest_int("max_depth", 3, 9, step=2)
        # minimum child weight, larger the term more conservative the tree.
        params["min_child_weight"] = trial.suggest_int("min_child_weight", 2, 10)
        params["eta"] = trial.suggest_float("eta", 1e-8, 1.0, log=True)
        # defines how selective algorithm is.
        params["gamma"] = trial.suggest_float("gamma", 1e-8, 1.0, log=True)
        params["grow_policy"] = trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"])

    if params["booster"] == "dart":
        params["sample_type"] = trial.suggest_categorical("sample_type", ["uniform", "weighted"])
        params["normalize_type"] = trial.suggest_categorical("normalize_type", ["tree", "forest"])
        params["rate_drop"] = trial.suggest_float("rate_drop", 1e-8, 1.0, log=True)
        params["skip_drop"] = trial.suggest_float("skip_drop", 1e-8, 1.0, log=True)


    score = []
    for df_train, df_valid in zip(df_trains, df_valids):
        clf = XGBClassifier(**params)
        clf.fit(df_train[features], df_train[target])
        
        pred = clf.predict(df_valid[features])
        true = df_valid[target].values
        score.append(accuracy(true, pred))
    score = np.mean(score)
    return score

# Hyperparameter Tuning
study = optuna.create_study(direction='maximize', sampler=TPESampler(seed=0), pruner=SuccessiveHalvingPruner())
study.optimize(objective, n_trials=50)
# Out:
# [I 2023-01-11 15:30:53,493] A new study created in memory with name: no-name-37e4e44f-0423-4621-8ab1-f77df97cc7cc
# [I 2023-01-11 15:30:54,538] Trial 0 finished with value: 0.9666666666666668 and parameters: {'booster': 'gblinear', 'lambda': 0.00022859433522173892, 'alpha': 2.4504079607415994e-05, 'subsample': 0.7167152904533249, 'colsample_bytree': 0.550069769010154}. Best is trial 0 with value: 0.9666666666666668.
# [I 2023-01-11 15:30:54,645] Trial 1 finished with value: 0.9666666666666668 and parameters: {'booster': 'gblinear', 'lambda': 0.021567524728780586, 'alpha': 0.0001702783205227671, 'subsample': 0.6544356488751459, 'colsample_bytree': 0.9404773106341289}. Best is trial 0 with value: 0.9666666666666668.
# [I 2023-01-11 15:30:54,747] Trial 2 finished with value: 0.9666666666666668 and parameters: {'booster': 'gblinear', 'lambda': 0.04580983888874032, 'alpha': 0.016797861943261036, 'subsample': 0.8960097185974554, 'colsample_bytree': 0.9828946737862112}. Best is trial 0 with value: 0.9666666666666668.
# [I 2023-01-11 15:30:54,993] Trial 3 finished with value: 0.925 and parameters: {'booster': 'gbtree', 'lambda': 8.834773237917946e-08, 'alpha': 0.001316340279131417, 'subsample': 0.31468262992723717, 'colsample_bytree': 0.9557351336396671, 'max_depth': 7, 'min_child_weight': 5, 'eta': 1.3075096319371512e-06, 'gamma': 0.01562678062781788, 'grow_policy': 'lossguide'}. Best is trial 0 with value: 0.9666666666666668.
# [I 2023-01-11 15:30:55,081] Trial 4 finished with value: 0.8083333333333333 and parameters: {'booster': 'gblinear', 'lambda': 0.0008619299566126549, 'alpha': 0.35480083081155517, 'subsample': 0.7454562392827868, 'colsample_bytree': 0.48760632045902885}. Best is trial 0 with value: 0.9666666666666668.
# [I 2023-01-11 15:30:55,213] Trial 5 finished with value: 0.975 and parameters: {'booster': 'gblinear', 'lambda': 0.0021584089022890717, 'alpha': 0.0023179440931861113, 'subsample': 0.36830604885907275, 'colsample_bytree': 0.30314103812388266}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:30:57,394] Trial 6 finished with value: 0.65 and parameters: {'booster': 'dart', 'lambda': 3.227097654537013e-05, 'alpha': 0.8072177525850062, 'subsample': 0.2816358485984225, 'colsample_bytree': 0.3671014048758678, 'max_depth': 3, 'min_child_weight': 7, 'eta': 1.0625094963538647e-06, 'gamma': 5.3763332795841517e-05, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 8.908433969329066e-06, 'skip_drop': 0.036978206108429786}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:30:57,501] Trial 7 finished with value: 0.8833333333333332 and parameters: {'booster': 'gblinear', 'lambda': 0.6481502906344189, 'alpha': 5.613188324247261e-05, 'subsample': 0.9814088705522697, 'colsample_bytree': 0.6838764157960369}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:30:57,820] Trial 8 finished with value: 0.95 and parameters: {'booster': 'gbtree', 'lambda': 9.153190258304556e-08, 'alpha': 2.3394920847694654e-06, 'subsample': 0.29498217516339525, 'colsample_bytree': 0.4543865435151808, 'max_depth': 5, 'min_child_weight': 2, 'eta': 0.003465588189977713, 'gamma': 0.0003410449582643011, 'grow_policy': 'lossguide'}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:30:59,926] Trial 9 finished with value: 0.95 and parameters: {'booster': 'dart', 'lambda': 3.5363205079386576e-06, 'alpha': 0.0021841529108138566, 'subsample': 0.30543828992351374, 'colsample_bytree': 0.7730617632948524, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.0004921567869290511, 'gamma': 1.4483061321722743e-08, 'grow_policy': 'depthwise', 'sample_type': 'uniform', 'normalize_type': 'forest', 'rate_drop': 9.77293810275356e-07, 'skip_drop': 0.0004066854878593079}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:00,195] Trial 10 finished with value: 0.9083333333333332 and parameters: {'booster': 'gbtree', 'lambda': 0.006279331789707024, 'alpha': 1.4660563998657165e-08, 'subsample': 0.4957754470627995, 'colsample_bytree': 0.22217815459837503, 'max_depth': 9, 'min_child_weight': 9, 'eta': 0.44511731725415593, 'gamma': 0.8245328215031723, 'grow_policy': 'lossguide'}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:00,315] Trial 11 finished with value: 0.9666666666666668 and parameters: {'booster': 'gblinear', 'lambda': 0.00010761739618006045, 'alpha': 4.710800275444875e-06, 'subsample': 0.5176996131734981, 'colsample_bytree': 0.22661674372959972}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:00,435] Trial 12 finished with value: 0.9666666666666668 and parameters: {'booster': 'gblinear', 'lambda': 0.0005515071070956345, 'alpha': 3.010680822725671e-07, 'subsample': 0.757292007761176, 'colsample_bytree': 0.5758929048597812}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:00,563] Trial 13 finished with value: 0.9666666666666668 and parameters: {'booster': 'gblinear', 'lambda': 8.331183133246784e-06, 'alpha': 5.31569468742796e-05, 'subsample': 0.42715841642798924, 'colsample_bytree': 0.3655477793994274}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:01,266] Trial 14 finished with value: 0.3583333333333333 and parameters: {'booster': 'dart', 'lambda': 0.0013307390904062086, 'alpha': 0.024911787873597147, 'subsample': 0.6307596217081503, 'colsample_bytree': 0.7210511002794031, 'max_depth': 9, 'min_child_weight': 10, 'eta': 1.480619019525673e-08, 'gamma': 2.8798707394953683e-08, 'grow_policy': 'depthwise', 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.8041393185473872, 'skip_drop': 4.909245122549208e-08}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:01,378] Trial 15 finished with value: 0.9666666666666668 and parameters: {'booster': 'gblinear', 'lambda': 1.382621797529177e-06, 'alpha': 0.0006426524974274475, 'subsample': 0.20006412624490355, 'colsample_bytree': 0.3525264919794671}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:01,493] Trial 16 finished with value: 0.9166666666666666 and parameters: {'booster': 'gblinear', 'lambda': 0.3765934319470915, 'alpha': 4.8803555171834404e-06, 'subsample': 0.8041169528531367, 'colsample_bytree': 0.6004127040723489}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:01,594] Trial 17 finished with value: 0.9583333333333334 and parameters: {'booster': 'gblinear', 'lambda': 7.455615405170186e-05, 'alpha': 0.01939383907923016, 'subsample': 0.444757213047024, 'colsample_bytree': 0.8353652814708076}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:01,808] Trial 18 finished with value: 0.925 and parameters: {'booster': 'gbtree', 'lambda': 0.00623020629192654, 'alpha': 3.0507042162516655e-07, 'subsample': 0.5823243405613974, 'colsample_bytree': 0.48395813748296546, 'max_depth': 3, 'min_child_weight': 6, 'eta': 0.1558416597893184, 'gamma': 3.7415732976112375e-06, 'grow_policy': 'depthwise'}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:03,314] Trial 19 finished with value: 0.95 and parameters: {'booster': 'dart', 'lambda': 6.784191403353148e-07, 'alpha': 1.4595377520313359e-05, 'subsample': 0.8608926290258361, 'colsample_bytree': 0.6009493397501778, 'max_depth': 7, 'min_child_weight': 8, 'eta': 1.1993088807010448e-05, 'gamma': 0.6169103373366082, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 1.037108073226885e-08, 'skip_drop': 1.1097742214921207e-08}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:03,418] Trial 20 finished with value: 0.975 and parameters: {'booster': 'gblinear', 'lambda': 0.00026894149893678476, 'alpha': 0.004410894657305185, 'subsample': 0.6947545374779047, 'colsample_bytree': 0.2897684728100514}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:03,523] Trial 21 finished with value: 0.9666666666666668 and parameters: {'booster': 'gblinear', 'lambda': 1.1082535348005267e-06, 'alpha': 0.0009659808419276077, 'subsample': 0.3668692810799544, 'colsample_bytree': 0.31517841564437477}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:03,635] Trial 22 finished with value: 0.975 and parameters: {'booster': 'gblinear', 'lambda': 0.00028684107368403926, 'alpha': 0.0043923486146797315, 'subsample': 0.6857230921249208, 'colsample_bytree': 0.28555360470182967}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:03,760] Trial 23 finished with value: 0.9666666666666668 and parameters: {'booster': 'gblinear', 'lambda': 1.9867021439059534e-05, 'alpha': 0.07487748492264888, 'subsample': 0.5799162647364893, 'colsample_bytree': 0.2736483472206859}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:03,875] Trial 24 finished with value: 0.9666666666666668 and parameters: {'booster': 'gblinear', 'lambda': 0.003022199848010074, 'alpha': 0.0071246028543430285, 'subsample': 0.6498108842708059, 'colsample_bytree': 0.42513764062530024}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:03,978] Trial 25 finished with value: 0.9666666666666668 and parameters: {'booster': 'gblinear', 'lambda': 0.09172882199595613, 'alpha': 0.0003072980255280631, 'subsample': 0.5462287025565655, 'colsample_bytree': 0.28227226992331383}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:04,090] Trial 26 finished with value: 0.975 and parameters: {'booster': 'gblinear', 'lambda': 0.000331349669662116, 'alpha': 0.004199281437087718, 'subsample': 0.6941177262713161, 'colsample_bytree': 0.2042838831683039}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:04,580] Trial 27 finished with value: 0.9416666666666667 and parameters: {'booster': 'gbtree', 'lambda': 1.0098838246625153e-08, 'alpha': 0.1471458899699322, 'subsample': 0.816635158332857, 'colsample_bytree': 0.22959166541872333, 'max_depth': 3, 'min_child_weight': 4, 'eta': 2.9529934455565172e-08, 'gamma': 1.191453311408634e-06, 'grow_policy': 'depthwise'}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:04,785] Trial 28 finished with value: 0.9666666666666668 and parameters: {'booster': 'gblinear', 'lambda': 0.010201126904094972, 'alpha': 0.0681543581029594, 'subsample': 0.20146504956773986, 'colsample_bytree': 0.4077539818841137}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:07,333] Trial 29 finished with value: 0.9333333333333333 and parameters: {'booster': 'dart', 'lambda': 0.0003443237527270349, 'alpha': 0.004296937103129166, 'subsample': 0.7027549130112077, 'colsample_bytree': 0.2021891955652135, 'max_depth': 7, 'min_child_weight': 2, 'eta': 0.010166309933066638, 'gamma': 0.004929874591485815, 'grow_policy': 'lossguide', 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.11192317589681398, 'skip_drop': 0.8674179614614882}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:07,639] Trial 30 finished with value: 0.9666666666666668 and parameters: {'booster': 'gblinear', 'lambda': 0.0001592307659907546, 'alpha': 0.0004213922800829462, 'subsample': 0.7005752244697367, 'colsample_bytree': 0.515322914038526}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:07,869] Trial 31 finished with value: 0.975 and parameters: {'booster': 'gblinear', 'lambda': 0.0021189246679409754, 'alpha': 0.005059586477410502, 'subsample': 0.6893954491916554, 'colsample_bytree': 0.2952552270820782}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:08,080] Trial 32 finished with value: 0.9666666666666668 and parameters: {'booster': 'gblinear', 'lambda': 0.002375390974095483, 'alpha': 0.008337051841868781, 'subsample': 0.620497792129726, 'colsample_bytree': 0.29868650490226}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:08,246] Trial 33 finished with value: 0.9666666666666668 and parameters: {'booster': 'gblinear', 'lambda': 0.0003035857343349014, 'alpha': 0.0001705030860811018, 'subsample': 0.7784963212108915, 'colsample_bytree': 0.25752920891701436}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:08,685] Trial 34 finished with value: 0.9583333333333334 and parameters: {'booster': 'gblinear', 'lambda': 0.03949604962642028, 'alpha': 0.001979024765686609, 'subsample': 0.666173404259005, 'colsample_bytree': 0.32907130686021624}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:09,184] Trial 35 finished with value: 0.9666666666666668 and parameters: {'booster': 'gblinear', 'lambda': 0.018038129308892106, 'alpha': 0.037766140376276076, 'subsample': 0.9209689551609564, 'colsample_bytree': 0.3816395245120709}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:09,731] Trial 36 finished with value: 0.9416666666666668 and parameters: {'booster': 'gblinear', 'lambda': 4.279307854637525e-05, 'alpha': 0.1761225485351603, 'subsample': 0.7353020624912445, 'colsample_bytree': 0.2524887651367581}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:10,103] Trial 37 finished with value: 0.975 and parameters: {'booster': 'gblinear', 'lambda': 0.0012805951095535076, 'alpha': 0.001664620025181142, 'subsample': 0.8559106411176125, 'colsample_bytree': 0.4132095573281482}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:10,508] Trial 38 finished with value: 0.9166666666666666 and parameters: {'booster': 'gbtree', 'lambda': 0.0014353625975524695, 'alpha': 0.00018796107341463182, 'subsample': 0.9563514862161541, 'colsample_bytree': 0.42366721298683885, 'max_depth': 5, 'min_child_weight': 10, 'eta': 9.195640850960928e-05, 'gamma': 8.298134033709135e-07, 'grow_policy': 'depthwise'}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:10,651] Trial 39 finished with value: 0.9583333333333334 and parameters: {'booster': 'gblinear', 'lambda': 0.13336518717000528, 'alpha': 0.010948039857998486, 'subsample': 0.8647806964341898, 'colsample_bytree': 0.33614643502732966}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:13,907] Trial 40 finished with value: 0.9166666666666666 and parameters: {'booster': 'dart', 'lambda': 1.9031031149904475e-05, 'alpha': 6.486889478263586e-05, 'subsample': 0.8529775912771507, 'colsample_bytree': 0.39495329367306836, 'max_depth': 9, 'min_child_weight': 6, 'eta': 4.316341868006611e-07, 'gamma': 0.019944213006961063, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.0022022750931421724, 'skip_drop': 1.5350361941116262e-05}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:14,056] Trial 41 finished with value: 0.9666666666666668 and parameters: {'booster': 'gblinear', 'lambda': 0.0008178284548993267, 'alpha': 0.0019657184972982785, 'subsample': 0.7865728799677295, 'colsample_bytree': 0.31465352798538054}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:14,219] Trial 42 finished with value: 0.975 and parameters: {'booster': 'gblinear', 'lambda': 0.003532932410407151, 'alpha': 0.0011310387247821215, 'subsample': 0.7302027855207192, 'colsample_bytree': 0.2390805667236355}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:14,465] Trial 43 finished with value: 0.975 and parameters: {'booster': 'gblinear', 'lambda': 0.002414005781365522, 'alpha': 0.0008934372614676753, 'subsample': 0.7396462923515458, 'colsample_bytree': 0.2350913351512636}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:14,654] Trial 44 finished with value: 0.9666666666666668 and parameters: {'booster': 'gblinear', 'lambda': 0.004338788245466781, 'alpha': 0.0005887390219674687, 'subsample': 0.6731467384102762, 'colsample_bytree': 0.2397129052046878}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:14,844] Trial 45 finished with value: 0.975 and parameters: {'booster': 'gblinear', 'lambda': 8.605830912850484e-05, 'alpha': 0.004396446936161624, 'subsample': 0.6057359915282244, 'colsample_bytree': 0.21561877202419585}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:15,011] Trial 46 finished with value: 0.9583333333333334 and parameters: {'booster': 'gblinear', 'lambda': 0.017395813163556352, 'alpha': 0.00011386963119511402, 'subsample': 0.7519306049799412, 'colsample_bytree': 0.45601456987615485}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:15,161] Trial 47 finished with value: 0.9666666666666668 and parameters: {'booster': 'gblinear', 'lambda': 9.39304052835881e-05, 'alpha': 2.6591204821077664e-05, 'subsample': 0.6020410689187776, 'colsample_bytree': 0.260480440027919}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:15,536] Trial 48 finished with value: 0.9416666666666667 and parameters: {'booster': 'gbtree', 'lambda': 0.00019091274744529102, 'alpha': 0.538184192706, 'subsample': 0.5522401040566265, 'colsample_bytree': 0.8546197278949863, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.006972189456431082, 'gamma': 5.244376169055126e-05, 'grow_policy': 'depthwise'}. Best is trial 5 with value: 0.975.
# [I 2023-01-11 15:31:15,656] Trial 49 finished with value: 0.9666666666666668 and parameters: {'booster': 'gblinear', 'lambda': 8.526321710096799e-06, 'alpha': 0.0009832511115095686, 'subsample': 0.7283200132958428, 'colsample_bytree': 0.2011170110302452}. Best is trial 5 with value: 0.975.

# %%
# Best Parameter로 모델 훈련
clfs = []
for df_train in df_trains:
    clf = XGBClassifier(**study.best_params)
    clf.fit(df_train[features], df_train[target])
    clfs.append(clf)
    

# 예측 수행 (soft voting)
pred = [clf.predict_proba(df_test[features]) for clf in clfs]
pred = np.mean(pred, axis=0)
pred = np.argmax(pred, axis=1)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(pred, df_test[target])
# Out:
# array([[ 7,  0,  0],
#        [ 0, 10,  1],
#        [ 0,  0, 12]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
print("예측 정확도 : {0:.4f}".format(accuracy_score(df_test[target], pred)))
# Out:
# 예측 정확도 : 0.9667
