# %%
import numpy as np
import pandas as pd
import optuna
from lightgbm import LGBMClassifier
from sklearn.model_selection import StratifiedKFold
from optuna.samplers import TPESampler
from optuna.pruners import SuccessiveHalvingPruner

# %%
df_data = pd.read_csv('data/iris.csv', sep=',')
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
from sklearn.preprocessing import LabelEncoder

items=['Setosa', 'Versicolor', 'Virginica']
encoder = LabelEncoder()
encoder.fit(items)
df_data['variety'] = encoder.transform(df_data['variety'])
df_data.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width  variety
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df_data, test_size=0.2)

# %%
df_train.head()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety
# 52            6.9          3.1           4.9          1.5        1
# 19            5.1          3.8           1.5          0.3        0
# 116           6.5          3.0           5.5          1.8        2
# 81            5.5          2.4           3.7          1.0        1
# 100           6.3          3.3           6.0          2.5        2

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120 entries, 52 to 35
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  120 non-null    float64
#  1   sepal.width   120 non-null    float64
#  2   petal.length  120 non-null    float64
#  3   petal.width   120 non-null    float64
#  4   variety       120 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.2 KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 74 to 25
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  30 non-null     float64
#  1   sepal.width   30 non-null     float64
#  2   petal.length  30 non-null     float64
#  3   petal.width   30 non-null     float64
#  4   variety       30 non-null     int32
# dtypes: float64(4), int32(1)
# memory usage: 1.3 KB

# %%
features = ['sepal.length', 'sepal.width', 'petal.length', 'petal.width']
target = 'variety'

# %%
df_train.reset_index()
# Out:
#      index  sepal.length  sepal.width  petal.length  petal.width  variety
# 0       52           6.9          3.1           4.9          1.5        1
# 1       19           5.1          3.8           1.5          0.3        0
# 2      116           6.5          3.0           5.5          1.8        2
# 3       81           5.5          2.4           3.7          1.0        1
# 4      100           6.3          3.3           6.0          2.5        2
# ..     ...           ...          ...           ...          ...      ...
# 115     51           6.4          3.2           4.5          1.5        1
# 116     42           4.4          3.2           1.3          0.2        0
# 117      6           4.6          3.4           1.4          0.3        0
# 118     55           5.7          2.8           4.5          1.3        1
# 119     35           5.0          3.2           1.2          0.2        0
#
# [120 rows x 6 columns]

# %%
df_trains = []
df_valids = []
skf = StratifiedKFold(n_splits=5, random_state=0, shuffle=True)
for train_index, valid_index in skf.split(df_train[features], df_train[target]):
    train = df_train.iloc[train_index]
    valid = df_train.iloc[valid_index]
    df_trains.append(train)
    df_valids.append(valid)

# %%
import optuna
def accuracy(true, pred):
    return np.mean(true==pred)

def objective(trial):
    params = {
        'num_leaves': trial.suggest_int('num_leaves', 2, 1024, step=1, log=True), 
        'max_depth': trial.suggest_int('max_depth', 1, 10, step=1, log=False), 
        'learning_rate': trial.suggest_float('learning_rate', 0.0001, 0.1, log=True), 
        'n_estimators': trial.suggest_int('n_estimators', 8, 1024, step=1, log=True), 
        'objective': 'multiclass', 
        'class_weight': trial.suggest_categorical('class_weight', ['balanced', None]),
        'min_child_samples': trial.suggest_int('min_child_samples', 10, 50, step=1, log=False), 
        'subsample': trial.suggest_uniform('subsample', 0.7, 1.0), 
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
        'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
        'random_state': 0
    }
    
    score = []
    for df_train, df_valid in zip(df_trains, df_valids):
        clf = LGBMClassifier(**params)
        clf.fit(df_train[features], df_train[target])
        
        pred = clf.predict(df_valid[features])
        true = df_valid[target].values
        score.append(accuracy(true, pred))
    score = np.mean(score)
    return score

# Hyperparameter Tuning
study = optuna.create_study(direction='maximize', sampler=TPESampler(seed=0), pruner=SuccessiveHalvingPruner())
study.optimize(objective, n_trials=50)
# Out:
# [I 2023-01-05 17:19:39,235] A new study created in memory with name: no-name-55d56567-5cac-408c-b8e7-4119c2cc62b0
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:39,360] Trial 0 finished with value: 0.9166666666666666 and parameters: {'num_leaves': 54, 'max_depth': 8, 'learning_rate': 0.006431172050131994, 'n_estimators': 109, 'class_weight': None, 'min_child_samples': 27, 'subsample': 0.9675319002346239, 'colsample_bytree': 0.9890988281503088, 'reg_alpha': 0.3834415188257777, 'reg_lambda': 7.917250380826646}. Best is trial 0 with value: 0.9166666666666666.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:39,394] Trial 1 finished with value: 0.75 and parameters: {'num_leaves': 47, 'max_depth': 6, 'learning_rate': 0.05981221901152557, 'n_estimators': 11, 'class_weight': 'balanced', 'min_child_samples': 44, 'subsample': 0.9334470252849552, 'colsample_bytree': 0.9610036444740457, 'reg_alpha': 0.978618342232764, 'reg_lambda': 7.9915856421672355}. Best is trial 0 with value: 0.9166666666666666.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:39,628] Trial 2 finished with value: 0.5 and parameters: {'num_leaves': 30, 'max_depth': 8, 'learning_rate': 0.00022637229697395497, 'n_estimators': 174, 'class_weight': None, 'min_child_samples': 31, 'subsample': 0.8243985819971571, 'colsample_bytree': 0.7793666836313881, 'reg_alpha': 0.7742336894342167, 'reg_lambda': 4.5615033221654855}. Best is trial 0 with value: 0.9166666666666666.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:39,849] Trial 3 finished with value: 0.925 and parameters: {'num_leaves': 61, 'max_depth': 1, 'learning_rate': 0.007126995609048582, 'n_estimators': 152, 'class_weight': None, 'min_child_samples': 37, 'subsample': 0.8078523701721357, 'colsample_bytree': 0.8311095861398023, 'reg_alpha': 0.6976311959272649, 'reg_lambda': 0.6022547162926983}. Best is trial 3 with value: 0.925.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:39,922] Trial 4 finished with value: 0.35 and parameters: {'num_leaves': 116, 'max_depth': 7, 'learning_rate': 0.0004277083049962072, 'n_estimators': 14, 'class_weight': None, 'min_child_samples': 33, 'subsample': 0.8315804540386961, 'colsample_bytree': 0.9965121514177678, 'reg_alpha': 0.10204481074802807, 'reg_lambda': 2.088767560948347}. Best is trial 3 with value: 0.925.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:40,083] Trial 5 finished with value: 0.9166666666666666 and parameters: {'num_leaves': 4, 'max_depth': 7, 'learning_rate': 0.000575274081411669, 'n_estimators': 74, 'class_weight': 'balanced', 'min_child_samples': 14, 'subsample': 0.896898876839582, 'colsample_bytree': 0.7414548854045842, 'reg_alpha': 0.1965823616800535, 'reg_lambda': 3.687251706609641}. Best is trial 3 with value: 0.925.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:40,124] Trial 6 finished with value: 0.35 and parameters: {'num_leaves': 319, 'max_depth': 1, 'learning_rate': 0.03264635677523523, 'n_estimators': 12, 'class_weight': 'balanced', 'min_child_samples': 50, 'subsample': 0.8814536559235138, 'colsample_bytree': 0.9217790738194904, 'reg_alpha': 0.039187792254320675, 'reg_lambda': 2.828069625764096}. Best is trial 3 with value: 0.925.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:40,194] Trial 7 finished with value: 0.7666666666666667 and parameters: {'num_leaves': 3, 'max_depth': 3, 'learning_rate': 0.00022708223335487552, 'n_estimators': 36, 'class_weight': 'balanced', 'min_child_samples': 38, 'subsample': 0.8699804362619725, 'colsample_bytree': 0.7796168472818336, 'reg_alpha': 0.5232480534666997, 'reg_lambda': 0.9394051075844168}. Best is trial 3 with value: 0.925.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:40,438] Trial 8 finished with value: 0.9166666666666666 and parameters: {'num_leaves': 64, 'max_depth': 10, 'learning_rate': 0.000903039728888594, 'n_estimators': 200, 'class_weight': None, 'min_child_samples': 21, 'subsample': 0.754957408602135, 'colsample_bytree': 0.8759538804430249, 'reg_alpha': 0.020107546187493552, 'reg_lambda': 8.289400292173632}. Best is trial 3 with value: 0.925.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:40,696] Trial 9 finished with value: 0.9 and parameters: {'num_leaves': 2, 'max_depth': 7, 'learning_rate': 0.0006456897906217104, 'n_estimators': 279, 'class_weight': 'balanced', 'min_child_samples': 33, 'subsample': 0.8776125793815517, 'colsample_bytree': 0.871675571737262, 'reg_alpha': 0.2230816326406183, 'reg_lambda': 9.52749011516985}. Best is trial 3 with value: 0.925.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:41,288] Trial 10 finished with value: 0.9333333333333332 and parameters: {'num_leaves': 696, 'max_depth': 3, 'learning_rate': 0.006927260760734906, 'n_estimators': 725, 'class_weight': None, 'min_child_samples': 42, 'subsample': 0.7178120820232871, 'colsample_bytree': 0.8154704690396714, 'reg_alpha': 0.6139695753623531, 'reg_lambda': 0.6252552841724102}. Best is trial 10 with value: 0.9333333333333332.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:42,044] Trial 11 finished with value: 0.9333333333333332 and parameters: {'num_leaves': 596, 'max_depth': 3, 'learning_rate': 0.005786967208840589, 'n_estimators': 921, 'class_weight': None, 'min_child_samples': 40, 'subsample': 0.7052883259751074, 'colsample_bytree': 0.819107015935575, 'reg_alpha': 0.6552427736058064, 'reg_lambda': 0.5686448950465631}. Best is trial 10 with value: 0.9333333333333332.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:42,811] Trial 12 finished with value: 0.9333333333333332 and parameters: {'num_leaves': 846, 'max_depth': 4, 'learning_rate': 0.0025690121003388907, 'n_estimators': 953, 'class_weight': None, 'min_child_samples': 42, 'subsample': 0.7024626464649452, 'colsample_bytree': 0.8212898809605089, 'reg_alpha': 0.6297547241499994, 'reg_lambda': 0.18635961662048683}. Best is trial 10 with value: 0.9333333333333332.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:42,970] Trial 13 finished with value: 0.35 and parameters: {'num_leaves': 920, 'max_depth': 3, 'learning_rate': 0.014753689334487985, 'n_estimators': 992, 'class_weight': None, 'min_child_samples': 49, 'subsample': 0.7083652734291532, 'colsample_bytree': 0.7043294863914207, 'reg_alpha': 0.8635396916543832, 'reg_lambda': 5.983441104261521}. Best is trial 10 with value: 0.9333333333333332.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:43,381] Trial 14 finished with value: 0.8916666666666666 and parameters: {'num_leaves': 391, 'max_depth': 4, 'learning_rate': 0.002115469780899972, 'n_estimators': 504, 'class_weight': None, 'min_child_samples': 42, 'subsample': 0.751609786456896, 'colsample_bytree': 0.7931154573886606, 'reg_alpha': 0.45439121724972525, 'reg_lambda': 1.8941231388894733}. Best is trial 10 with value: 0.9333333333333332.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:43,788] Trial 15 finished with value: 0.925 and parameters: {'num_leaves': 223, 'max_depth': 3, 'learning_rate': 0.01196274463246105, 'n_estimators': 446, 'class_weight': None, 'min_child_samples': 27, 'subsample': 0.7644795107119832, 'colsample_bytree': 0.876484343002708, 'reg_alpha': 0.5542891342828025, 'reg_lambda': 5.876770646264434}. Best is trial 10 with value: 0.9333333333333332.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:44,147] Trial 16 finished with value: 0.95 and parameters: {'num_leaves': 15, 'max_depth': 2, 'learning_rate': 0.02315965143439751, 'n_estimators': 489, 'class_weight': None, 'min_child_samples': 45, 'subsample': 0.7795306590922159, 'colsample_bytree': 0.9268445962802053, 'reg_alpha': 0.32559648400124175, 'reg_lambda': 1.7542659978316526}. Best is trial 16 with value: 0.95.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:44,480] Trial 17 finished with value: 0.7916666666666667 and parameters: {'num_leaves': 9, 'max_depth': 5, 'learning_rate': 0.002468836245159782, 'n_estimators': 370, 'class_weight': None, 'min_child_samples': 46, 'subsample': 0.7891351511792274, 'colsample_bytree': 0.9254966675375501, 'reg_alpha': 0.3747935135323063, 'reg_lambda': 3.2045618471582764}. Best is trial 16 with value: 0.95.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:44,841] Trial 18 finished with value: 0.95 and parameters: {'num_leaves': 16, 'max_depth': 1, 'learning_rate': 0.09515492948366741, 'n_estimators': 585, 'class_weight': None, 'min_child_samples': 46, 'subsample': 0.7367549102156076, 'colsample_bytree': 0.9185200944229633, 'reg_alpha': 0.3277545426099781, 'reg_lambda': 0.01286693413425255}. Best is trial 16 with value: 0.95.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:44,953] Trial 19 finished with value: 0.925 and parameters: {'num_leaves': 14, 'max_depth': 1, 'learning_rate': 0.07970151758025866, 'n_estimators': 58, 'class_weight': None, 'min_child_samples': 10, 'subsample': 0.7803941357268552, 'colsample_bytree': 0.9233415632881624, 'reg_alpha': 0.28721766062899506, 'reg_lambda': 1.794840399413219}. Best is trial 16 with value: 0.95.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:45,027] Trial 20 finished with value: 0.6583333333333334 and parameters: {'num_leaves': 17, 'max_depth': 2, 'learning_rate': 0.032402827346010014, 'n_estimators': 30, 'class_weight': None, 'min_child_samples': 47, 'subsample': 0.7412359356483204, 'colsample_bytree': 0.9563127370698511, 'reg_alpha': 0.3183962163813293, 'reg_lambda': 4.225115378074596}. Best is trial 16 with value: 0.95.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:45,470] Trial 21 finished with value: 0.9333333333333333 and parameters: {'num_leaves': 8, 'max_depth': 2, 'learning_rate': 0.025848408102884208, 'n_estimators': 610, 'class_weight': None, 'min_child_samples': 37, 'subsample': 0.7282381782582916, 'colsample_bytree': 0.9003532410324255, 'reg_alpha': 0.4717174423153697, 'reg_lambda': 1.415988403901479}. Best is trial 16 with value: 0.95.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:45,882] Trial 22 finished with value: 0.925 and parameters: {'num_leaves': 6, 'max_depth': 2, 'learning_rate': 0.034405570345173005, 'n_estimators': 534, 'class_weight': None, 'min_child_samples': 36, 'subsample': 0.7310197413211028, 'colsample_bytree': 0.8979832829467171, 'reg_alpha': 0.4506809496363397, 'reg_lambda': 1.48179010534247}. Best is trial 16 with value: 0.95.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:46,136] Trial 23 finished with value: 0.9333333333333332 and parameters: {'num_leaves': 20, 'max_depth': 2, 'learning_rate': 0.019343742227185018, 'n_estimators': 304, 'class_weight': None, 'min_child_samples': 46, 'subsample': 0.7885032470337727, 'colsample_bytree': 0.9014140834952348, 'reg_alpha': 0.16747610787479322, 'reg_lambda': 2.687320444451772}. Best is trial 16 with value: 0.95.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:46,569] Trial 24 finished with value: 0.9333333333333333 and parameters: {'num_leaves': 8, 'max_depth': 1, 'learning_rate': 0.09952639854535023, 'n_estimators': 603, 'class_weight': None, 'min_child_samples': 39, 'subsample': 0.7336403706705488, 'colsample_bytree': 0.9411064313626673, 'reg_alpha': 0.3028489815161063, 'reg_lambda': 0.1278621322148603}. Best is trial 16 with value: 0.95.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:46,664] Trial 25 finished with value: 0.35 and parameters: {'num_leaves': 26, 'max_depth': 1, 'learning_rate': 0.09336140641392868, 'n_estimators': 286, 'class_weight': None, 'min_child_samples': 50, 'subsample': 0.7640556963893733, 'colsample_bytree': 0.9597662391834386, 'reg_alpha': 0.28630809927280065, 'reg_lambda': 0.1552659205703181}. Best is trial 16 with value: 0.95.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# ...
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:52,012] Trial 41 finished with value: 0.95 and parameters: {'num_leaves': 13, 'max_depth': 3, 'learning_rate': 0.02844428842982891, 'n_estimators': 487, 'class_weight': 'balanced', 'min_child_samples': 45, 'subsample': 0.8322479317607434, 'colsample_bytree': 0.9125997986436487, 'reg_alpha': 0.34457717866888893, 'reg_lambda': 2.056383684182837}. Best is trial 16 with value: 0.95.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:52,094] Trial 42 finished with value: 0.6083333333333332 and parameters: {'num_leaves': 25, 'max_depth': 3, 'learning_rate': 0.026537923707100192, 'n_estimators': 8, 'class_weight': None, 'min_child_samples': 47, 'subsample': 0.8317816048196678, 'colsample_bytree': 0.9174906429173844, 'reg_alpha': 0.34369514460770884, 'reg_lambda': 1.9108048878520996}. Best is trial 16 with value: 0.95.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:52,267] Trial 43 finished with value: 0.35 and parameters: {'num_leaves': 65, 'max_depth': 1, 'learning_rate': 0.07243890345797838, 'n_estimators': 743, 'class_weight': 'balanced', 'min_child_samples': 50, 'subsample': 0.7815895699899863, 'colsample_bytree': 0.8881469987639544, 'reg_alpha': 0.5001645345620773, 'reg_lambda': 2.8674291531830796}. Best is trial 16 with value: 0.95.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:52,888] Trial 44 finished with value: 0.9 and parameters: {'num_leaves': 16, 'max_depth': 3, 'learning_rate': 0.0013156343201939493, 'n_estimators': 553, 'class_weight': None, 'min_child_samples': 41, 'subsample': 0.7996542829174934, 'colsample_bytree': 0.9381581739877171, 'reg_alpha': 0.40752983397471676, 'reg_lambda': 0.5612257851344402}. Best is trial 16 with value: 0.95.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:53,313] Trial 45 finished with value: 0.95 and parameters: {'num_leaves': 34, 'max_depth': 3, 'learning_rate': 0.027807595733579753, 'n_estimators': 363, 'class_weight': 'balanced', 'min_child_samples': 44, 'subsample': 0.8352557758747242, 'colsample_bytree': 0.9135672318541157, 'reg_alpha': 0.27191581889660693, 'reg_lambda': 2.2107673182647285}. Best is trial 16 with value: 0.95.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:54,115] Trial 46 finished with value: 0.9416666666666667 and parameters: {'num_leaves': 37, 'max_depth': 2, 'learning_rate': 0.030699030413460122, 'n_estimators': 823, 'class_weight': None, 'min_child_samples': 38, 'subsample': 0.8283172630975731, 'colsample_bytree': 0.9132617760120305, 'reg_alpha': 0.179150057412705, 'reg_lambda': 1.718892785511623}. Best is trial 16 with value: 0.95.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:54,495] Trial 47 finished with value: 0.9333333333333332 and parameters: {'num_leaves': 86, 'max_depth': 3, 'learning_rate': 0.01613268766322559, 'n_estimators': 336, 'class_weight': 'balanced', 'min_child_samples': 43, 'subsample': 0.8886189760789418, 'colsample_bytree': 0.869005551113114, 'reg_alpha': 0.26500866886360763, 'reg_lambda': 3.6597284144960254}. Best is trial 16 with value: 0.95.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:54,681] Trial 48 finished with value: 0.55 and parameters: {'num_leaves': 2, 'max_depth': 4, 'learning_rate': 0.05421232150553753, 'n_estimators': 221, 'class_weight': None, 'min_child_samples': 48, 'subsample': 0.8649409730520814, 'colsample_bytree': 0.8297389777937169, 'reg_alpha': 0.9967707010631459, 'reg_lambda': 0.333831472419601}. Best is trial 16 with value: 0.95.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1156672498.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
# [I 2023-01-05 17:19:54,843] Trial 49 finished with value: 0.9333333333333332 and parameters: {'num_leaves': 50, 'max_depth': 1, 'learning_rate': 0.008559800280393303, 'n_estimators': 74, 'class_weight': 'balanced', 'min_child_samples': 34, 'subsample': 0.8778357936449913, 'colsample_bytree': 0.9325019476214255, 'reg_alpha': 0.3525779033846051, 'reg_lambda': 2.3055972635962467}. Best is trial 16 with value: 0.95.

# %%
# Best Parameter로 모델 훈련
clfs = []
for df_train in df_trains:
    clf = LGBMClassifier(**study.best_params)
    clf.fit(df_train[features], df_train[target])
    clfs.append(clf)
    

# 예측 수행 (soft voting)
pred = [clf.predict_proba(df_test[features]) for clf in clfs]
pred = np.mean(pred, axis=0)
pred = np.argmax(pred, axis=1)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(pred, df_test[target])
# Out:
# array([[11,  0,  0],
#        [ 0,  8,  0],
#        [ 0,  0, 11]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
print("예측 정확도 : {0:.4f}".format(accuracy_score(df_test[target], pred)))
# Out:
# 예측 정확도 : 1.0000
